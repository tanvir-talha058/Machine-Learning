# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvir-talha058/Machine-Learning/blob/main/image_processing_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io
import matplotlib.pyplot as plt

image = io.imread('hasuapa.jpg')

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import numpy as np

# Flip vertically
flipped_image = np.flipud(image)

plt.imshow(flipped_image)
plt.axis('off')
plt.show()

# %%
cropped_image = image[50:300, 100:400]
plt.imshow(cropped_image)
plt.axis('off')
plt.show()

# %%
from skimage.transform import rescale
zoomed_image = rescale(image, 1.5, anti_aliasing=True, channel_axis=-1)

plt.imshow(zoomed_image)
plt.axis('off')
plt.show()

# %%
from skimage.color import rgb2gray

# grayscale
gray_image = rgb2gray(image)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
from skimage.exposure import adjust_gamma
bright_image = adjust_gamma(image, gamma=0.5)
plt.imshow(bright_image)
plt.axis('off')
plt.show()
